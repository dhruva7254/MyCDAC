# %%
#1. Write a Python program to create a tuple.
t1=(1,2,3)
t2=("ghgh",)
t3=(34,"jk",[2,3,4],{1,5,7},{'a':23,'b':34})
print(t1,t2,t3)
# Out:
# (1, 2, 3) ('ghgh',) (34, 'jk', [2, 3, 4], {1, 5, 7}, {'a': 23, 'b': 34})

# %%
# 3. Write a Python program to create a tuple of numbers and print one item.
t1=(1,2,3)
print(t1[1],t1[0:2],t1[:3])
# Out:
# 2 (1, 2) (1, 2, 3)

# %%
# 4. Write a Python program to unpack a tuple into several variables.
v1,v2 = (1,2)
print(v1,v2)
# v1,v2 = (1,2,3) #error
# print(v1,v2)
# v1,v2 = (1,) # error
# print(v1,v2)
# Out:
# 1 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-f41e26d62d2a> in <cell line: 6>()
#       4 # v1,v2 = (1,2,3)
#       5 # print(v1,v2)
# ----> 6 v1,v2 = (1)
#       7 print(v1,v2)
#
# TypeError: cannot unpack non-iterable int object

# %%
# 5. Write a Python program to add an item to a tuple.
t1=(5,7,8)
t1.add(45) #WRONG ... cant modify tuple!!!!
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-a9428c9c76d2> in <cell line: 3>()
#       1 # 5. Write a Python program to add an item to a tuple.
#       2 t1=(5,7,8)
# ----> 3 t1.add(45)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
# 6. Write a Python program to convert a tuple to a string.
t1=(2,3,4)
s1= str((2,3,4))
print(s1)
# Out:
# (2, 3, 4)

# %%
t2=('I','A','C','S','D')
"".join(t2)
# Out:
# 'IACSD'

# %%
t1=(2,3,4)
s1=""
for e1 in t1:
    s1 += str(e1)
print(s1,int(s1))
s1= "".join(t1) # error
print(s1)
# Out:
# 234 234
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-f49ca35917b9> in <cell line: 6>()
#       4     s1 += str(e1)
#       5 print(s1,int(s1))
# ----> 6 s1= "".join(t1) # error
#       7 print(s1)
#
# TypeError: sequence item 0: expected str instance, int found

# %% [markdown]
# # 9. Write a Python program to find repeated items in a tuple.

# %%
t1=(9,9,9,9,9,23,45,67,67,10)
#M1 two for loop
#M2 use count function t1.count(9)
#M3 use set

# %%
# m3 using set
for e1 in set(t1):
    if t1.count(e1) > 1:
        print("repeated elem", e1)
# Out:
# repeated elem 67
# repeated elem 9

# %%
repeated_set = set()
for idx1 in range(len(t1)):
    for idx2 in range(len(t1)):
        if (idx1 != idx2) and (t1[idx1] == t1[idx2]) and (t1[idx1] not in repeated_set):
            repeated_set.add(t1[idx1])
print(repeated_set)
# Out:
# {9, 67}

# %%
# 17. Write a Python program to unzip a list of tuples into individual lists.

list_of_tuple = [(1,2),(90,67),(23,45)]
for tup in list_of_tuple:
    print(list(tup))
# Out:
# [1, 2]
# [90, 67]
# [23, 45]

# %%
# 18. Write a Python program to reverse a tuple.
t1=(1,2,3,4)
print(t1[::-1], tuple(reversed(t1)))
# Out:
# (4, 3, 2, 1) (4, 3, 2, 1)

# %%
# 19. Write a Python program to convert a list of tuples into a dictionary.
l_t=[(1,2),(4,5)]
dict(l_t)
# Out:
# {1: 2, 4: 5}

# %%
# 20. Write a Python program to print a tuple with string formatting.
# Sample tuple : (100, 200, 300)
# Output : This is a tuple (100, 200, 300)

t1=(1,2,3)
print("This is a tuple", str(t1))
# Out:
# This is a tuple (1, 2, 3)

# %%
t=(1,2,3)
tuple((*t[:2],4))
# Out:
# (1, 2, 4)

# %%
# 23. Write a Python program to sort a tuple by its float element.
# Sample data: [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
# Expected Output: [('item3', '24.5'), ('item2', '15.10'), ('item1', '12.20')]

# l= [('item1', 12.20), ('item2', 15.10), ('item3', 24.5)]
l=[('1',1.2),('2',33.4),('3',78.6),('4',5.4),('5',45)]
l1=[ t[1] for t in l]
l1.sort(reverse=True)#[78.6, 45, 33.4, 5.4, 1.2]
# print(l1)
l2=[()]*len(l1)
for tup in l:
    idx = l1.index(tup[1])
    l2[idx]=tup
print(l2)
# Out:
# [78.6, 45, 33.4, 5.4, 1.2]
# [('3', 78.6), ('5', 45), ('2', 33.4), ('4', 5.4), ('1', 1.2)]
