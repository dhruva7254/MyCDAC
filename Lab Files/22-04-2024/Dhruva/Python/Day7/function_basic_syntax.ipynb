# %%
def add(a,b):
    c=a+b
    return c

add(2,3)
# Out:
# 5

# %%
def add(a :int ,b:int): # its type hint .. not compulsory
    """
    add two nos and return addition
    """
    c=a+b
    return c
v1=2
v2=3
add(v1,v2)
# Out:
# 5

# %%
print(type(add), id(add))
# Out:
# <class 'function'> 137987688576720

# %%
add=4
print(type(add), id(add))
# Out:
# <class 'int'> 137988118315344

# %%
add(3,4)
# Out:
# 7

# %%
def mul():
    product=1
    for i in range(1,100,2):
        product = product * i
    return product
mul()
# Out:
# 2725392139750729502980713245400918633290796330545803413734328823443106201171875

# %%
def fact(n:int):
    product=1
    for i in range(2,n+1):
        product = product * i
    return product
num = fact(100)
print(len(str(num)), num)
# Out:
# 158 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %% [markdown]
# # Function which returns nothing (None)
#
# None is special symbol in python
#
# It means nothing
#
# By default truth value of None is False
#
# So, bool(None) is False

# %%
def fun1():
    print("hello")
    return
fun1()
# Out:
# hello

# %%
r = fun1()
print(r)
# Out:
# hello
# None

# %%
def fun2():
    print("hello")

r = fun2()
print(r)
# Out:
# hello
# None

# %%
def fun2():
    print("hello")
print("hi")
fun2()
# Out:
# hi
# hello

# %%
def fun2():
    print("hello")
    print("hi")
fun2()
# Out:
# hello
# hi

# %% [markdown]
# # recurssive function

# %%
count=3
def hello_fun():
    global count
    if count > 0: # breaking condition
        print("hello")
        count -=1
        hello_fun() # call the function itself
    else:
        pass # dont call the recurssive function!!!
hello_fun()
# Out:
# hello
# hello
# hello

# %%
def hello_fun(count):
    if count > 0: # breaking condition
        print("hello")
        hello_fun(count-1) # call the function itself
    else:
        pass # dont call the recurssive function!!!
hello_fun(3)
# Out:
# hello
# hello
# hello

# %% [markdown]
# # function mutable parameter working

# %%
def fun2(l:list):
    l[0]=10

l1=[3,4,5]
print(id(l1),l1)
fun2(l1)
print(id(l1), l1)
# Out:
# 137986837418048 [3, 4, 5]
# 137986837418048 [10, 4, 5]

# %%
def fun2(l:list):
    # l[0]=10
    l=[12,34]
    print("l:",id(l),l)

l1=[3,4,5]
print("before call l1:",id(l1),l1)
fun2(l1)
print("after call l1:",id(l1), l1)
# Out:
# before call l1: 137986837028608 [3, 4, 5]
# l: 137986837021696 [12, 34]
# after call l1: 137986837028608 [3, 4, 5]

# %% [markdown]
# # standard arguments

# %%
def add(a,b):
    c=a+b
    return c

print(add(2,3))
print(add(b=5,a=45))
# Out:
# 5
# 50

# %%
def add(a,b=2,/,c=9):
    pass
# Out:
#   File "<ipython-input-25-72e980fdd9a8>", line 1
#     def add(a,b=2,/,c,d=34,*,e,f=56,**k,u=9):
#                     ^
# SyntaxError: non-default argument follows default argument

# %%
add(3)
